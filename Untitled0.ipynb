# %% [markdown]
# <a href="https://colab.research.google.com/github/1561398583/ihome/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 2
x = x + 1
x
# Out:
# 3

# %% [markdown]
# ![images.jpg](data:image/jpeg;base64,...)
